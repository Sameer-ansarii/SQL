# %% [markdown]
# ### Q) What is SQL and why is it important for data analysis?
#
# `SQL (Structured Query Language)` is a programming language used to manage, manipulate and fetch data from `relational databases`. It is important for data analysis as it allows analysts to `retrieve, filter, aggregate, and manipulate data stored in databases`, making it a powerful tool for extracting insights and generating reports.
#
# **OR**
#
# `SQL` stands for `Structured Query Language`. It is a programming language used to interact with `relational databases`.

# %% [markdown]
# ### Q) Use of SQL?
#
# **CRUD**
#
# * `Create`
#
#
# * `Read`
#
#
# * `Update`
#
#
# * `Delete`

# %% [markdown]
# ### Q) What is MYSQL and it's use?
#
# `MySQL` is a open-source and free `RDMS (relational database management system)` used to `store, manage and manipulate databases`.

# %% [markdown]
# ### Q) Difference between SQL and MYSQL.
#
# `SQL (Structured Query Language)` is a programming language used to manage and manipulate relational databases.
#
# `MySQL`, on the other hand, is a specific `relational database management system (RDMS)` that uses SQL as its language for `interacting with the database`. `MySQL` is an `open-source` and `free RDMS` that implements the SQL language and provides the software and tools to `store, manage, and retrieve data.`

# %% [markdown]
# ### Q) Difference between SQL, My SQL and No SQL?
#
# `MySQL` is a relational database management system that uses `SQL`. Whereas `SQL` is primarily used to query and operate database systems, `MySQL` enables you to store, handle, delete, and modify data in an organized way.
#
# As for `NoSQL`, it is a non-relational database that does not use `SQL`. `NoSQL` databases use a simpler data structure, meaning they are quicker, more responsive, and more scalable than traditional relational databases.

# %% [markdown]
# ### Q) Difference between My SQL and No SQL.
#
# * MySQL and NoSQL are two different types of databases. MySQL is a relational database, while NoSQL is a non-relational database.
#
#
# * MySQL is more popular than NoSQL because it has been around longer and has a larger community.
#
#
# * NoSQL databases are more flexible than MySQL because they can store unstructured data.
#
#
# * MySQL is not as scalable as NoSQL because it has a rigid schema.
#
#
# * MySQL requires a detailed database model before it can be created, while NoSQL does not.
#
#
# * MySQL has a wider range of reporting tools than NoSQL.
#
#
# * NoSQL databases use JSON (JavaScript Object Notation), XML, YAML, or binary schema, facilitating unstructured data. SQL has a fixed-defined schema, while NoSQL databases are more flexible.
#
# |Feature	|MySQL|	NoSQL|
# |-----------|------|------|
# |Type|	Relational database	|Non-relational database|
# |Popularity|	More popular|	Less popular|
# |Data storage|	Tabular|	Document-based|
# |Schema|	Fixed	|Dynamic|
# |Scalability	|Not as scalable|	More scalable|
# |Reporting tools	|More reporting tools|	Fewer reporting tools|

# %% [markdown]
# ![1_WCPKGdWossvP6N64L7xrMQ.png](attachment:1_WCPKGdWossvP6N64L7xrMQ.png)

# %% [markdown]
# ### Q)  Difference between RDMS and Non-RDMS?
#
# **`RDMS`**
#
# **`Data Model`**: RDBMS uses a structured data model based on tables, rows, and columns, where data is organized into predefined schemas and tables with relationships defined through keys.
#
#
# **`Query Language`**: RDBMS typically uses SQL (Structured Query Language) to manipulate and retrieve data from the database.
#
#
# **`Examples`**: MySQL, Oracle Database, PostgreSQL, Microsoft SQL Server.
#
#
# **`Non-Relational Database Management System (NoSQL or Non-SQL DBMS)`**
#
# **`Data Model`**: NoSQL databases use various data models like key-value, document, columnar, and graph. These models are more flexible and dynamic, allowing unstructured and semi-structured data to be stored.
#
#
# **`Query Language`**: NoSQL databases use different query languages depending on the specific database type, such as MongoDB's query language for document databases.
#
#
# **`Examples`**: MongoDB, Cassandra, Redis, Neo4j.

# %% [markdown]
# ### Q) What is primary key and foreign key?
#
# **`Primary Key`**
#
# * Primary Key is a unique column we set in a table to easily identify and locate data in queries.
#
#
# * A table can have only one primary key, which should be unique and Not Null.
#
# **`Foreign Key`**
#
# * A foreign is a column used to link 2 or more tables together.
#
#
# * A table can have any number of foreign keys, can contains duplicate and null values.

# %% [markdown]
# ![Primary%20key%20vs%20Foreign%20key%20in%20SQL%202019.png](attachment:Primary%20key%20vs%20Foreign%20key%20in%20SQL%202019.png)

# %% [markdown]
# ### Q) What is the difference between a primary key and a foreign key?
#
# * A primary key is a column or a set of columns that uniquely identify each record in a table. It enforces data integrity and ensures that each row has a unique identifier.
#
#
# * A foreign key, on the other hand, is a column that establishes a relationship between two tables. It refers to the primary key of another table and maintains referential integrity.

# %% [markdown]
# ### Q) What are Constraints?
#
# • Constraints are used to specify rules for data in a table
#
#
# • This ensures the accuracy and reliability of the data in the table
#
#
# • Constraints can be specified when the table is created with the CREATE TABLE statement, or after the table is created with the ALTER TABLE statement
#
# • **`Syntax`**
#
# CREATE TABLE table_name(
#
# column1 datatype **`constraint`**,
#
# column2 datatype **`constraint`**,
#
# column3 datatype **`constraint`**,);
#
# **`Constraints`**
#
# Commonly used constraints in SQL:
#
# * `NOT NULL` - Ensures that a column cannot have a NULL value
#
#
# * `NIQUE` - Ensures that all values in a column are different
#
#
# * `PRIMARY KEY` - A combination of a NOT NULL and UNIQUE
#
#
# * `FOREIGN KEY` - Prevents actions that would destroy links between tables (used to link multiple tables together)
#
#
# * `CHECK` -Ensures that the values in a column satisfies a specific condition
#
#
# * `DEFAULT` - Sets a default value for a column if no value is specified
#
#
# * `CREATE INDEX` - Used to create and retrieve data from the da very quickly

# %% [markdown]
# ### Q) What is the use of `WHERE` Clause?
#
# `WHERE` Clause is used to filter records. It is used to extract only those records that fulfil a specified condition.

# %% [markdown]
# ### Q) What is the use of `LIMIT` Clause?
#
# The `LIMIT` clause is used to specify the number of records to return.
#
# The `LIMIT` clause is useful on large tables with thousands of records. Returning a large number of records can impact performance.

# %% [markdown]
# ### Q) What is the use of `ORDER BY` Clause?
# `Order By` keyword is used to sort the values of a column in ascending order.
#
#
# The `ORDER BY` keyword is used to sort the result-set in ascending or descending order.
#
#
# The `ORDER BY` keyword sorts the records in ascending order by default. To sort the records in descending order, use the `DESC` keyword.

# %% [markdown]
# ### Q) What is the use of `GROUP BY` Statement?
#
# The `GROUP BY` statement groups rows that have the same values into summary rows.
#
#
# It is often used with aggregate functions `COUNT()`, `MAX()`, `MIN()`, `SUM()`, `AVG()` to group the result-set by one or more columns.
#
#
# **NOTE:-**
#
# * All (*) is not used with `GROUP BY`.
#
#
# * `GROUP BY` Statement is used with aggregate functions.
#
#
# * `HAVING` Clause is used with `GROUP BY`, if you use `WHERE` Clause with `GROUP BY` it will show error.
#
#
# * The column we use with `select` statement is also comes with `group by`. EG : **Select `Mode`, SUM(Amount) From Payment GROUP BY `Mode`;**

# %% [markdown]
# ### Q) What is the use of `HAVING` Clause?
#
# The `HAVING` clause is used to apply a filter on the result of GROUP BY based on the specified condition.
#
#
# The `WHERE` clause places conditions on the selected columns, whereas the `HAVING` clause places conditions on groups created by the `GROUP BY` clause.
#
#
# The `HAVING` clause was added to SQL because the `WHERE` keyword cannot be used with `group by` & aggregate functions.

# %% [markdown]
# ### Q) Which Function is used to show TIME AND DATE in SQL?
#
# * SELECT `NOW()` : retrieve the current timestamp, including both the date and time
#
#
# * SELECT `TIMEOFDAY()` : retrieve the current time of day
#
#
# * SELECT `CURRENT_TIME` : retrieve the current time
#
#
# * SELECT `CURRENT_DATE` : retrieve the current date

# %% [markdown]
# ### Q) What is `JOIN` and their types?
#
# Join means combine something.
#
#
# A `JOIN` clause is used to combine data from two or more tables, based on a related column between them.
#
#
# **TYPES OF JOINS**
#
#
# 1) **`INNER JOIN`** : Returns records that have matching values in both tables
#
#
# 2) **`LEFT JOIN`** / **`LEFT OUTER JOIN`** : Returns all records from the left table, and the matched records from the right table. If matched records are not found it will show NULL on the right table.
#
#
# 3) **`RIGHT JOIN`** / **`RIGHT OUTER JOIN`** : Returns all records from the right table, and the matched records from the left table.  If matched records are not found it will show NULL on the left table.
#
#
# 4) **`OUTER JOIN`** : Returns all records from both tables. If there is no matches values are present it will shown NULL over their.
#
#
# 5) **`SELF JOIN`**
#
#
# * A self join is a regular join in which a table is joined to itself.
#
#
# * Self Join are powerful for comparing values in a column of rows with the same table.

# %% [markdown]
# ### Q) How would you approach combining data from multiple tables using SQL joins?
#
# To combine data from multiple tables, you would use SQL joins based on the relationship between the tables. You would identify the common columns between the tables and use the appropriate join type (e.g., INNER JOIN, LEFT JOIN) to retrieve the desired data. You can specify the join conditions using the ON clause or the USING clause for natural joins.

# %% [markdown]
# ### Q) What is the use of `UNION` Operator?
#
#
# The `UNION` operator is used to combine the result-set of two or more `SELECT` statements exclusing duplicates.
#
#
# To use UNION Operatore each SELECT Statement must have:
#
#
# * Every `SELECT` statement within `UNION` must have the same number of columns
#
#
# * The columns must also have similar data types
#
#
# * The columns in every `SELECT` statement must also be in the same order

# %% [markdown]
# ### Q) What is the use of `UNION ALL` Operator?
#
# The `UNIONALL` operator is used to combine the result-set of two or more `SELECT` statements including duplicates.  It simply concatenates the rows from each SELECT statement, including duplicates if they exist.
#
#
# **NOTE: Every assumption is same as `UNION`.

# %% [markdown]
# ### Q) What is the difference between UNION and UNION ALL in SQL?
#
# * UNION combines the result sets of two or more SELECT statements and removes duplicates.
#
#
# * UNION ALL, on the other hand, combines the result sets but retains all rows, including duplicates.

# %% [markdown]
# ### Q) What is SUb-Query?
#
# A `sub query` or inner `inner query` or a `nested query` allows us to create complex query on the output of another query.
#
# * `Sub Query` syntax invloves two `SELECT` Statements.
# --------------------------
#
# **SELECT COLUMN_NAME(S)**
#
# **FROM TABLE_NAME**
#
# **`WHERE` COLUMN_NAME CONDITION**
#
# **(SELECT COLUMN_NAME FROM TABLE_NAME `WHERE` CONDITION)**

# %% [markdown]
# ### Q) What is the use of `EXISTS` Operator?
#
# The `EXISTS` operator is used to test for the existence of any record in a subquery.
#
# -------------------
#
#
# **SELECT first_name, last_name From Customers AS C**
#
# **WHERE `EXISTS`(SELECT customer_id, amount FROM Payment AS P WHERE P.customer_id = C.customer_id AND amount > 100)**

# %% [markdown]
# ### Q) What is the ue of `CASE` Statement?
#
# The `CASE` statement goes through conditions and returns a value when the first condition is met (like an if-then-else statement). So, once a condition is true, it will stop reading and return the result. If no conditions are true, it returns the value in the ELSE clause.
#
# If there is no `ELSE` part and no conditions are true, it returns NULL.
#
# **`CASE`**
#
#    **`WHEN` condition1 `THEN` result1**
#
#    **`WHEN` condition2 `THEN` result2**
#
#    **`WHEN` conditionN `THEN` resultN**
#
#    **`ELSE` result**
#
# **`END`;**

# %% [markdown]
# ### Q) What are aggregate functions in SQL? Provide some examples.
#
# Aggregate functions perform calculations on a set of rows and return a single value. Examples include SUM, AVG, COUNT, MAX, and MIN. For example: SELECT COUNT(*) FROM table.

# %% [markdown]
# ### Q) What is the difference between GROUP BY and ORDER BY in SQL?
#
# GROUP BY is used to group rows based on one or more columns, often used with aggregate functions. ORDER BY is used to sort the result set based on specified columns.

# %% [markdown]
# ### Q) Explain the concept of subqueries in SQL and provide an example of how they can be used.
#
# Subqueries are queries nested within another query. They are used to retrieve data for more complex queries. Example: SELECT * FROM table WHERE column IN (SELECT column FROM another_table).

# %% [markdown]
# ### Q) How do you optimize SQL queries for performance? Share some best practices.
#
# Some best practices for optimizing SQL queries include using proper indexing, minimizing the use of wildcard characters, avoiding unnecessary joins and subqueries, and using appropriate data types.
#
#
# * Avoid using multiple OR in the FILTER predicate
#
#
# * Use wildcards at the end of a phrase only
#
#
# * Avoid too many JOINs
#
#
# * Avoid using SELECT DISTINCT
#
#
# * Use SELECT fields instead of SELECT *
#
#
# * Run the query during off-peak hours
#
#
# * Create joins with INNER JOIN (not WHERE)
#
#
# * Minimize large write operations

# %% [markdown]
# ### Q) What is the purpose of the DISTINCT keyword in SQL? When would you use it?
#
# The DISTINCT keyword is used to eliminate duplicate rows in the result set. It ensures that only unique values are returned. It is used when you want to retrieve unique values from a specific column or combination of columns.

# %% [markdown]
# ### Q) How do you handle duplicates in a table using SQL?
#
# To handle duplicates, you can use the DISTINCT keyword to retrieve unique values or the GROUP BY clause to group and aggregate data. You can also use the ROW_NUMBER() function to assign row numbers to each row and filter based on row numbers.

# %% [markdown]
# ### Q) What are indexes in SQL? When and why would you use them?
#
# `CREATE INDEX` Statement
#
# * The CREATE INDEX statement is used to create indexes in tables.
#
# * Indexes are used to retrieve data from the database more quickly than otherwise. The users cannot see the indexes, they are just used to speed up searches/queries.
#
# * Note: Updating a table with indexes takes more time than updating a table without (because the indexes also need an update). So, only create indexes on columns that will be frequently searched against.
#
# **CREATE INDEX index_name**
#
# **ON table_name (column1, column2, ...);**

# %% [markdown]
# ### Q) Difference between WHERE and HAVING Clause?
#
# WHERE and HAVING clauses are used to give conditions in SQL queries.
#
#
# * WHERE clause is used with the SELECT statement to filter rows based on specific conditions. It is used before group by clasue or any aggregation function.
#
#
# * The HAVING clause is used with the GROUP BY clause to filter rows after the group by and aggregation function. It is used filters the result after the grouping and aggregation have occurred.

# %% [markdown]
# ### Q) What are Window Functions and their types?
#
# Window Functions in SQL are used for Data Analysis. These functions perform calculations across multiple rows. There are 3 types of Window Functions such as, Aggregate Functions, Ranking Functions and Value Functions. Window Functions are used with OVER clause to define function.

# %% [markdown]
# ### Q) If you multiple categories in a column and you have to find the largest of each category by another column in SQL. What function you should use?
#
# I use row_number() function to give row number to each observation of all categories and used where clause to filter row_number(). EG: Where row_number <=1.

# %% [markdown]
# ### Q) Explain the concept of normalization in databases and its benefits.
#
# Normalization is the process of organizing data in a database. It includes creating tables and establishing relationships between those tables according to rules designed both to protect the data and to make the database more flexible by eliminating redundancy and inconsistent dependency.

# %% [markdown]
# ![WhatsApp%20Image%202023-07-16%20at%2018.25.51.jpg](attachment:WhatsApp%20Image%202023-07-16%20at%2018.25.51.jpg)

# %% [markdown]
# ![WhatsApp%20Image%202023-07-16%20at%2018.25.50.jpg](attachment:WhatsApp%20Image%202023-07-16%20at%2018.25.50.jpg)

# %% [markdown]
# **Sol: Method 1**
#
# SELECT greatest(source, destination), least(source, destination), max(distance)
#
# from travel
#
# group by greatest(source, destination), least(source, destination);
#
# -------------
#
# **Sol: Method 2**
#
# SELECT *
#
# FROM travel AS t1
#
# WHERE NOT EXISTS (SELECT *
#
# FROM travel AS t2
#
# WHERE t1.source = t2.destination
#
# AND t1.destination = t2.source
#
# AND t1.destination > t2.destination);

# %% [markdown]
# ![WhatsApp%20Image%202023-07-16%20at%2018.52.26.jpg](attachment:WhatsApp%20Image%202023-07-16%20at%2018.52.26.jpg)

# %% [markdown]
# **Sol:**
#
# With cte As(
#
# SELECT *, ROW_NUMBER() OVER (ORDER BY team ASC) AS id
#
# FROM match)
#
# SELECT * FROM cte as a
#
# JOIN cte as b
#
# ON a.team <> b.team
#
# WHERE a.id < b.id;

# %% [markdown]
# ![WhatsApp%20Image%202023-07-16%20at%2019.09.33.jpg](attachment:WhatsApp%20Image%202023-07-16%20at%2019.09.33.jpg)

# %% [markdown]
# **Sol:**
#
# WITH cte AS (
#
# SELECT *, CONCAT(id, ' ', name) AS con,
#
# NTILE(4) OVER (ORDER BY id ASC) AS groups
#
# FROM emp)
#
# SELECT `STRING_AGG`(con, ', ') AS results, groups
#
# FROM cte
#
# GROUP BY groups
#
# ORDER BY groups;

# %% [markdown]
# **Work of `STRING_AGG`**
#
# SELECT `STRING_AGG`(name, ', ') as results, groups
#
# FROM emp
#
# **Output:**
#
# Emp1, Emp2, Emp3, Emp4....

# %% [markdown]
# ### Q) How do you handle NULL values in SQL queries? Can you provide examples?
#
# To handle NULL values, you can use the IS NULL or IS NOT NULL operators in the WHERE clause. For example: SELECT * FROM table WHERE column IS NULL

# %% [markdown]
# ### Q) How to find NULL Values in Table?
#
# **SELECT column1, column2, ...**
#
# **FROM your_table**
#
# **WHERE column_name `IS NULL`;**

# %% [markdown]
# ### Q) How to fetch unique records from a table in SQL?
#
# **SELECT `DISTINCT` column1, column2, ...**
# **FROM table_name;**

# %% [markdown]
# ### Q) How to insert a new column in table?
#
# **`ALTER TABLE` table_name**
#
# **`ADD` column_name `data_type`;**
#
# --------------
#
# **`ALTER TABLE` employees**
#
# **`ADD` email `VARCHAR(100)`;**

# %% [markdown]
# ### Q) You have a 'Name' column in a table. Wite a SQL query to extract only those records where 'son' is present in 'Name' column.

# %% [markdown]
# ***SELECT * FROM table_name `WHERE` Name `LIKE` '%son%';**

# %% [markdown]
# ### Q) You have a table which have 4 different columns, such as ID, Age, Marks, Country. Write a query in SQL to see that how many students belong to each country.

# %% [markdown]
# **SELECT `COUNT(ID)` `AS` Total_Students, Country**
#
# **FROM Table_Name**
#
# **`GROUP BY` Country**
#
# **`ORDER BY` Total_Students `DESC`;**

# %% [markdown]
# ### Q) Q) A table consits of columns 'Order_ID' and 'Order_Date'. Write a SQL query to extract only those records where more than 5 orders are place in a particular date.

# %% [markdown]
# **SELECT Order_Date, `COUNT(Order_ID)` `as` TotalOrders**
#
# **FROM table_name**
#
# **`GROUP BY` Order_Date**
#
# **`HAVING` `COUNT(Order_ID)` > 5;**

# %% [markdown]
# ### Q) In a table we have 2 columns, such as 'ID' and 'Name' and 'ID' columns contains mutliple duplicate values. Write a query in SQL to see the duplicate rows.

# %% [markdown]
# **SELECT ID, Name, `COUNT(*)` `as` DuplicateCount**
#
# **FROM table_name**
#
# **`GROUP BY` ID, Name**
#
# **`HAVING` `COUNT(*)` `>` 1;**

# %% [markdown]
# ### Q) Write a SQL query to extract only that record which having the second highest salary?

# %% [markdown]
# ***SELECT * FROM employees**
#
# **`WHERE` salary = (SELECT MAX(salary) FROM employees**
#
# **`WHERE` salary < (SELECT MAX(salary)**
#
# **FROM employees));**

# %% [markdown]
# ![WhatsApp%20Image%202023-07-14%20at%2016.18.50.jpg](attachment:WhatsApp%20Image%202023-07-14%20at%2016.18.50.jpg)

# %% [markdown]
# ![WhatsApp%20Image%202023-07-14%20at%2016.18.50s.jpg](attachment:WhatsApp%20Image%202023-07-14%20at%2016.18.50s.jpg)
