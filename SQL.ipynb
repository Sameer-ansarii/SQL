# %% [markdown]
# **Note:-**
#
# * MySQL is a widely used relational database management system (RDBMS).
#
#
# * MySQL is free and open-source.
#
#
# * MySQL is ideal for both small and large applications.

# %% [markdown]
# ### Q) What is MySQL?
#
# * MySQL is a relational database management system
#
#
# * MySQL is open-source
#
#
# * MySQL is free
#
#
# * MySQL is ideal for both small and large applications
#
#
# * MySQL is very fast, reliable, scalable, and easy to use
#
#
# * MySQL is cross-platform
#
#
# * MySQL is compliant with the ANSI SQL standard
#
#
# * MySQL was first released in 1995
#
#
# * MySQL is developed, distributed, and supported by Oracle Corporation
#
#
# * MySQL is named after co-founder Monty Widenius's daughter: My

# %% [markdown]
# ### Q) What is RDBMS?
#
# * RDBMS stands for Relational Database Management System.
#
#
# * RDBMS is a program used to maintain a relational database.
#
#
# * RDBMS is the basis for all modern database systems such as MySQL, Microsoft SQL Server, Oracle, and Microsoft Access.
#
#
# * RDBMS uses SQL queries to access the data in the database.

# %% [markdown]
# ### Q) What is SQL?
# SQL stands for Structured Query Language. It is a standard language which is used to deal with databases. We can manipulate and fetch data from databases using SQL.

# %% [markdown]
# ### Semicolon after SQL Statements?
# * Some database systems require a semicolon at the end of each SQL statement.
#
#
# * Semicolon is the standard way to separate each SQL statement in database systems that allow more than one SQL statement to be executed in the same call to the server.

# %% [markdown]
# ### Some of The Most Important SQL Commands
# `SELECT` - extracts data from a database
#
# `UPDATE` - updates data in a database
#
# `DELETE` - deletes data from a database
#
# `INSERT INTO` - inserts new data into a database
#
# `CREATE DATABASE` - creates a new database
#
# `ALTER DATABASE` - modifies a database
#
# `CREATE TABLE` - creates a new table
#
# `ALTER TABLE` - modifies a table
#
# `DROP TABLE` - deletes a table
#
# `CREATE INDEX` - creates an index (search key)
#
# `DROP INDEX` - deletes an index

# %% [markdown]
# ### Syntax & Keywords used in ascending order to write a query
#
# `SELECT`
#
#
# `FROM`
#
#
# `WHERE`
#
#
# `GROUPBY`
#
#
# `HAVING`
#
#
# `ORDERBY`
#
#
# `LIMIT`

# %% [markdown]
# **Note:-**
#
# * SQL keywords are NOT case sensitive: `select` is the same as `SELECT`
#
#
# * Always write a categories of column in `strings`, i.e ('Category 1', 'Category 2'...)
#
#
# * If categories of column are in `interger`, then write it simple, i.e (1,2,3...)

# %% [markdown]
# **Show databases;**
#
# **Use database_name;**
#
# **show tables;**
#
# ***select * from table_name**
#
#
# **Note:-** Run all these queries to show database and use it.

# %% [markdown]
# ### `GREATEST` and `LEAST` Function
# -------------
# **SELECT `GREATEST`(1,10,100)**
#
# Output: 100
#
# **SELECT `GREATEST`(Akash, Dharti, Vayu)**
#
# Output: Akash
#
# -----------
#
# **SELECT `LEAST`(1,10,100)**
#
# Output: 1
#
# **SELECT `LEAST`(Akash, Dharti, Vayu)**
#
# Output: Vayu

# %% [markdown]
# ### 1) `SELECT` Statement
#
# The `SELECT` statement is used to select data from a database.
#
# The data returned is stored in a result table, called the result-set.

# %% [markdown]
# `SELECT` Syntax
#
# **`SELECT` column1, column2,... FROM table_name;**

# %% [markdown]
# **OR**
#
# ***`SELECT` * FROM table_name;**

# %% [markdown]
# ### 2) `SELECT DISTINCT`
#
# DISTINCT keyword is used to see and fetch the unique values of a column in a table.
#
#
# **SELECT `DISTINCT` Country FROM Customers;**

# %% [markdown]
# **OR**

# %% [markdown]
# **SELECT `DISTINT` Country,City FROM Customers;**

# %% [markdown]
# i.e: Country and CIty are columns and Customers is a Table.

# %% [markdown]
# ### 3) `COUNT (DISTINCT Column Name)`

# %% [markdown]
# `COUNT (DISTINCT Column Name)` is used to see the count of unique value present in a column.

# %% [markdown]
# **SELECT COUNT(DISTINCT Country) FROM Customers;**

# %% [markdown]
# ### 4) `Aliases`
#
# * `Aliases` are used to give a table, or a column in a table, a temporary name.
#
#
# * `Aliases` are often used to make column names more readable.
#
#
# * An `alias` only exists for the duration of that query.
#
#
# * An `alias` is created with the `AS` keyword.

# %% [markdown]
# **SELECT column_name `AS` alias_name
# FROM table_name;**

# %% [markdown]
# **SELECT column_name(s)
# FROM table_name `AS` alias_name;**

# %% [markdown]
# **SELECT CustomerID `AS` ID, CustomerName `AS` Customer
# FROM Customers;**

# %% [markdown]
# **SELECT Country `AS` CNT FROM Customers;**

# %% [markdown]
# **SELECT `COUNT(DISTINCT Country)` `AS` abc FROM Customers;**

# %% [markdown]
# **SELECT CustomerName, `CONCAT_WS`(', ', Address, PostalCode, City, Country) `AS` Address
# FROM Customers;**
#
# It is used to concate values of column and `','` it is used to comma seprate the values.
#
# |CustomerName|	Address|
# |-------------|----------|
# |Alfreds Futterkiste|	Obere Str. 57, 12209, Berlin, Germany|
# |Ana Trujillo Emparedados y helados|	Avda. de la Constitución 2222, 05021, México D.F., Mexico|

# %% [markdown]
# ### 5) `ORDER BY`

# %% [markdown]
# * `Order By` keyword is used to sort the values of a column in ascending order.
#
#
# * The `ORDER BY` keyword is used to sort the result-set in ascending or descending order.
#
#
# * The `ORDER BY` keyword sorts the records in ascending order by default. To sort the records in descending order, use the `DESC` keyword.

# %% [markdown]
# **SELECT column1, column2, ... FROM table_name `ORDER BY` column1, column2, ... ASC|DESC;**

# %% [markdown]
# **SELECT DISTINCT Country FROM Customers `ORDER BY` Country;**

# %% [markdown]
# ***SELECT * FROM Customers `ORDER BY` Country `ASC`, City `DESC`**

# %% [markdown]
# ### 6) Use `ORDER BY` with `Asc` & `Desc`

# %% [markdown]
# * `ORDER BY` Column Name `Desc` keyword is used to sort the values of a column in descending order.

# %% [markdown]
# **SELECT DISTINCT Country FROM Customers `ORDER BY` Country `Desc`;**

# %% [markdown]
# ***SELECT * FROM Customers `ORDER BY` Country `Asc`, `ORDER By` CustomerName `Desc`;**

# %% [markdown]
# ### 7) `WHERE`

# %% [markdown]
# * The `WHERE` clause is used to filter records.
#
#
# * It is used to extract only those records that fulfill a specified condition.
#
#
# * The `WHERE` clause can be combined with `AND`, `OR`, and `NOT` operators.
#
#
# * The `AND` and `OR` operators are used to filter records based on more than one condition:
#
#
# |Operator|Description|
# |--------|-----------|
# |=	|Equal|
# |>	|Greater than|
# |<	|Less than|
# |>=	|Greater than or equal|
# |<=	|Less than or equal|
# |<> / !=	|Not equal.|
# |BETWEEN	|Between a certain range|
# |LIKE	|Search for a pattern|
# |IN	|To specify multiple possible values for a column|

# %% [markdown]
# ***SELECT * FROM Customers `WHERE` Country='GERMANY';**

# %% [markdown]
# ***SELECT * FROM Customers WHERE CustomerID=1;**

# %% [markdown]
# ### 8) Use of `WHERE` clause with `<>` (Not equal) symbol

# %% [markdown]
# `<>` (Not equal) symbol retrieve rows where the value doesn't match

# %% [markdown]
# ***SELECT * FROM Customers `WHERE` City `<>` 'Germany';**

# %% [markdown]
# ### 9) Use of `WHERE` clause with`>` (Greater Than) Symbol

# %% [markdown]
# `>` (Greater Than) symbol retrieve rows where the value is greater than the given value

# %% [markdown]
# ***SELECT * FROM Customers `WHERE` CustomerID `>` 5;**

# %% [markdown]
# **OR**

# %% [markdown]
# ***SELECT * FROM Customers  `WHERE`  CustomerID `>=` 5;**

# %% [markdown]
# ### 10) Use of `WHERE` clause with `<` (Lesser Than) Symbol

# %% [markdown]
# `<` (Lesser Than) symbol retrieve rows where the value is lesser than the given value

# %% [markdown]
# ***SELECT * FROM Customers `WHERE` CustomerID `<` 5;**

# %% [markdown]
# **OR**

# %% [markdown]
# ***SELECT * FROM Customers `WHERE` CustomerID `<=` 5;**

# %% [markdown]
# ### 11) Use of `WHERE` clause with `And` Operator

# %% [markdown]
# * The `AND` operator is used to specify that all conditions must be true for a row.
#
#
# * The `AND` operator displays a record if all the conditions separated by `AND` are TRUE.

# %% [markdown]
# **SELECT column1, column2, ... FROM table_name `WHERE` condition1 `AND` condition2 `AND` condition3 ...;**

# %% [markdown]
# ***SELECT * FROM Customers `WHERE` Country='UK' `and` City='London';**

# %% [markdown]
# ### 12) Use of `WHERE` clause with `OR` Operator

# %% [markdown]
# * The `OR` operator is used to specify that at least one of the conditions must be true.
#
#
# * The `OR` operator displays a record if any of the conditions separated by `OR` is TRUE.

# %% [markdown]
# **SELECT column1, column2, ... FROM table_name `WHERE` condition1 `OR` condition2 `OR` condition3 ...;**

# %% [markdown]
# ***SELECT * FROM Customers `WHERE` Country='UK' `or` Country='Germany';**

# %% [markdown]
# ### 13) Use of `WHERE` clause with `NOT` Operator

# %% [markdown]
# The `NOT` operator displays a record if the condition(s) is NOT TRUE.

# %% [markdown]
# **SELECT column1, column2, ... FROM table_name WHERE NOT condition;**

# %% [markdown]
# ***SELECT * FROM Customers WHERE NOT Country = 'Germany';**

# %% [markdown]
# ### 14) Combining `AND`, `OR` and `NOT`  with `WHERE` Clause

# %% [markdown]
# ***SELECT * FROM Customers WHERE Country = 'Germany' `AND` (City = 'Berlin'  OR` City = 'Stuttgart');**

# %% [markdown]
# ***SELECT * FROM Customers `WHERE` `NOT` Country = 'Germany' `AND` `NOT` Country = 'USA';**

# %% [markdown]
# ### 15) Use of `WHERE`  clause with  `IN` Operator

# %% [markdown]
# * The `IN` operator is used to display rows where the condition match.
#
#
# * The `IN` operator allows you to specify multiple values in a `WHERE` clause.
#
#
# * The `IN` operator is a shorthand for multiple OR conditions.

# %% [markdown]
# **SELECT column_name(s) FROM table_name `WHERE` column_name `IN` (value1, value2, ...);**

# %% [markdown]
# **SELECT column_name(s) FROM table_name `WHERE` column_name `IN` (SELECT STATEMENT);**

# %% [markdown]
# ***SELECT * FROM Customers `Where` Country `IN` ('Germany','UK');**

# %% [markdown]
# ***SELECT * FROM Customers `Where` CutomerID `IN` (1,2,3,4);**

# %% [markdown]
# ***SELECT * FROM Customers
# `WHERE` Country `IN` (SELECT Country FROM Suppliers);**
#
# Show records of all Countries in Customers Table which present in Country column of Suppliers Table.

# %% [markdown]
# **Note:-** Inner query is always run first then outer query.

# %% [markdown]
# ### 16) Use of `WHERE` clause with `NOT IN` Operator

# %% [markdown]
# The `NOT IN` operator is used to retrieve rows where the value of a column does not match

# %% [markdown]
# ***SELECT * FROM Customers `WHERE` CustomerID `NOT IN` (1,2,3,4);**

# %% [markdown]
# ### 17) Use of `Where` clause with `BETWEEEN` Operator
#
# `Between` Operater is used to display recores Between a certain range.
#
#
# The `BETWEEN` operator selects values within a given range. The values can be numbers, text, or dates.
#
#
# The  BETWEEN` operator is inclusive: begin and end values are included.

# %% [markdown]
# **SELECT column_name(s)
# FROM table_name
# `WHERE` column_name `BETWEEN` value1 AND value2;**

# %% [markdown]
# ***SELECT * FROM Customers `WHERE` CustomerID `BETWEEN` 20 `AND` 30;**

# %% [markdown]
# ***SELECT * FROM Customers `WHERE` CustomerID `BETWEEN` 20 `AND` 30 `ORDER BY` Country;**

# %% [markdown]
# ***SELECT * FROM Products
# `WHERE` Price `NOT BETWEEN` 10 AND 20;**

# %% [markdown]
# ***SELECT * FROM Products
# `WHERE` Price `BETWEEN` 10 AND 20
# `AND` CategoryID `NOT IN` (1,2,3);**

# %% [markdown]
# ***SELECT * FROM Products
# `WHERE` ProductName `BETWEEN` 'Carnarvon Tigers' `AND` 'Mozzarella di Giovanni'
# `ORDER BY` ProductName;**

# %% [markdown]
# ***SELECT * FROM Products
# `WHERE` ProductName `NOT BETWEEN` 'Carnarvon Tigers' `AND` 'Mozzarella di Giovanni'
# `ORDER BY` ProductName;**

# %% [markdown]
# ***SELECT * FROM Orders
# `WHERE` OrderDate `BETWEEN` '1996-07-01' `AND` '1996-07-31';**

# %% [markdown]
# ### 18) Use of `Where` clause with `LIKE` Operator
#
# The `LIKE` operator is used in a `WHERE` clause to search for a specified pattern in a column.
#
# There are two wildcards often used in conjunction with the LIKE operator:
#
# The percent sign (%) represents zero, one, or multiple characters
#
# The underscore sign (_) represents one, single character
#
# The percent sign and the underscore can also be used in combinations!
#
# |LIKE Operator|	Description|
# |-------------|------------|
# |WHERE CustomerName LIKE 'a%'	|Finds any values that start with "a"|
# |WHERE CustomerName LIKE '%a'	|Finds any values that end with "a"|
# |WHERE CustomerName LIKE '%or%'	|Finds any values that have "or" in any position|
# |WHERE CustomerName LIKE '_r%'	|Finds any values that have "r" in the second position|
# |WHERE CustomerName LIKE 'a_%'	|Finds any values that start with "a" and are at least 2 characters in length|
# |WHERE CustomerName LIKE 'a__%'	|Finds any values that start with "a" and are at least 3 characters in length|
# |WHERE ContactName LIKE 'a%o'	|Finds any values that start with "a" and ends with "o"|

# %% [markdown]
# ***SELECT * FROM Customers `WHERE` City `LIKE` 's%';**
#
#
# Return all records where city name is starts with s

# %% [markdown]
# ***SELECT * FROM Customers `WHERE` City `LIKE` 'A%o%';**

# %% [markdown]
# ***SELECT * FROM Customers
# `WHERE` City `LIKE` '_ondon';**

# %% [markdown]
# ### SUB QUERY
#
# A `sub query` or inner `inner query` or a `nested query` allows us to create complex query on the output of another query.
#
# * `Sub Query` syntax invloves two `SELECT` Statements.
#
# ------------
#
# **SELECT COLUMN_NAME(S)**
#
# **FROM TABLE_NAME**
#
# **WHERE COLUMN_NAME CONDITION**
#
# **(SELECT COLUMN_NAME FROM TABLE_NAME WHERE CONDITION);**
#
# ------------------
#
# ***SELECT * FROM payment**
#
# **WHERE amount > (SELECT avg(amount) from payment);**
#
# ---------
#
#
# ### `We can perform joining with the help of sub query`
#
# **SELECT cust_id, amount, mode FROM `payment`**
#
# **WHERE cust_id IN (SELECT cust_id from `customers`);**

# %% [markdown]
# ### 19 `INSERT INTO`

# %% [markdown]
# * It is possible to write the INSERT INTO statement in two ways:
#
# 1. Specify both the column names and the values to be inserted:
#
#
# **`INSERT INTO` table_name (column1, column2, column3, ...)
# VALUES (value1, value2, value3, ...);**
#
#
# **`INSERT INTO` Customers (CustomerName, City, Country)
# VALUES ('Cardinal', 'Stavanger', 'Norway');**

# %% [markdown]
# 2. If you are adding values for all the columns of the table, you do not need to specify the column names in the SQL query. However, make sure the order of the values is in the same order as the columns in the table. Here, the INSERT INTO syntax would be as follows:
#
# **`INSERT INTO` table_name
# VALUES (value1, value2, value3, ...);**
#
#
# **`INSERT INTO` Customers (CustomerName, ContactName, Address, City, PostalCode, Country)
# VALUES ('Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway');**

# %% [markdown]
# **Note:-** If a field in a table is optional, it is possible to insert a new record or update a record without adding a value to this field. Then, the field will be saved with a NULL value.

# %% [markdown]
# ### 20) `IS NULL` Syntax
#
# It is not possible to test for NULL values with comparison operators, such as =, <, or <>.
#
# We will have to use the `IS NULL` and `IS NOT NULL` operators instead.

# %% [markdown]
# **SELECT column_names FROM table_name `WHERE` column_name `IS NULL`;**

# %% [markdown]
# **SELECT CustomerName, ContactName, Address FROM Customers `WHERE` Address `IS NULL`;**

# %% [markdown]
# **Tip:** Always use IS NULL to look for NULL values.

# %% [markdown]
# ### 21) `IS NOT NULL` Operator
#
# The `IS NOT NULL` operator is used to test for non-empty values (NOT NULL values).

# %% [markdown]
# **SELECT column_names FROM table_name `WHERE` column_name `IS NOT NULL`;**

# %% [markdown]
# **SELECT CustomerName, ContactName, Address FROM Customers `WHERE` Address `IS NOT NULL`;**

# %% [markdown]
# ### 22) `UPDATE` Syntax
#
# The `UPDATE` statement is used to modify the existing records in a table.

# %% [markdown]
# **`UPDATE` table_name `SET` column1 = value1, column2 = value2, ... `WHERE` condition;**

# %% [markdown]
# **`UPDATE` Customers `SET` ContactName = 'Alfred Schmidt', City = 'Frankfurt' `WHERE` CustomerID = 1;**

# %% [markdown]
# ### 23) `UPDATE` Multiple Records

# %% [markdown]
# It is the `WHERE` clause that determines how many records will be updated.

# %% [markdown]
# **`UPDATE` Customers `SET` PostalCode = 00000 `WHERE` Country = 'Mexico';**

# %% [markdown]
# ### Update Warning!

# %% [markdown]
# Be careful when updating records. If you omit the WHERE clause, ALL records will be updated!

# %% [markdown]
# **`UPDATE` Customers `SET` PostalCode = 00000;**
#
# |PostalCode|
# |----------|
# |00000|
# |00000|
# |00000|
# |00000|
# |00000|

# %% [markdown]
# ### 24) `DELETE` Syntax
#
# The `DELETE` statement is used to delete existing records in a table.

# %% [markdown]
# **`DELETE` FROM table_name `WHERE` condition;**

# %% [markdown]
# **`DELETE` FROM Customers `WHERE` CustomerName='Alfreds Futterkiste';**

# %% [markdown]
# ### Delete All Records
# It is possible to delete all rows in a table without deleting the table. This means that the table structure, attributes, and indexes will be intact:

# %% [markdown]
# ### Q) 25 `LIMIT` Clause

# %% [markdown]
# The `LIMIT` clause is used to specify the number of records to return.
#
# The `LIMIT` clause is useful on large tables with thousands of records. Returning a large number of records can impact performance.

# %% [markdown]
# **SELECT column_name(s)
# FROM table_name
# `WHERE` condition
# `LIMIT` number;**

# %% [markdown]
# ***SELECT * FROM Customers
# `LIMIT` 3;**

# %% [markdown]
# ***SELECT * FROM Customers
# `WHERE` Country='Germany'
# `LIMIT` 3;**

# %% [markdown]
# # Functions In SQL
#
# Functions in SQL are the database objects that contains a set of SQL statements to perform a specific task. A function accepts input parameters, perform actions, and then return the result.
#
# Types of Function:
#
# 1. System Defined Function: these are built-in functions • Example: `rand()`, `round()`, `upper()`, `lower()`, `count()`, `sum()`, `max()`, etc.
#
#
# 2. User-Defined Function: Once you define a function, can call it in the same way as the built-in functions.

# %% [markdown]
# # Most Used String Functions
#
# String functions are used to perform an operation on input string and return an output string
#
# * `UPPER()` converts the value of a field to uppercase. Eg : **select `upper(area_type)` from "House_Data";**
#
#
# * `LOWER()` converts the value of a field to lowercase. Eg : **select `lower(area_type)` from "House_Data";**
#
#
# * `LENGTH()` returns the length of the value in a text field. Eg : **select `length(area_type)`, area_type from "House_Data";**
#
#
# * `SUBSTRING()` extracts a substring from a string. Eg : **select `substring(area_type, 1, 3)`, area_type FROM "House_Data";**
#
#
# * `NOW()` returns the current system date and time.
#
#
# * `FORMAT()` used to set the format of a field
#
#
# * `CONCAT()` adds two or more strings together. Eg : **select `concat(area_type, availability)` as ABC FROM "House_Data";**
#
#
# * `REPLACE()` Replaces all occurrences of a substring within a string, with a new subst. Eg : **select `replace (area_type, 'Super', 'Duper')` From "House_Data";**
#
#
# * `TRIM()` removes leading and trailing spaces (or other specified characters) from a start and end

# %% [markdown]
# **https://www.postgresql.org/docs/9.1/functions-string.html**

# %% [markdown]
# # `Aggregate Functions`

# %% [markdown]
# **Most Used `Aggregate Functions`**
#
# `Aggregate function` performs a calculation on multiple values and returns a single value.
#
# And `Aggregate function` are often used with `GROUP BY` &  `SELECT` statement.
#
# **`COUNT()`** :  returns number of values
#
# **`SUM()`** : returns sum of all values
#
# **`AVG()`** : returns average value
#
# **`MAX()`** : returns maximum value
#
# **`MIN()`** : returns minimum value
#
# **`ROUND()`** : Rounds a number to a specified number of decimal places. EG : **SELECT `ROUND(AVG(amount), 2)` FROM payment;**

# %% [markdown]
# **https://www.postgresql.org/docs/9.5/functions-aggregate.html**

# %% [markdown]
# ### 26) `MIN()`

# %% [markdown]
# The `MIN()` function returns the smallest value of the selected column.

# %% [markdown]
# **SELECT `MIN(column_name)`
# FROM table_name
# `WHERE` condition;**

# %% [markdown]
# **SELECT `MIN(Price)` `AS` SmallestPrice
# FROM Products;**

# %% [markdown]
# ### 27) `MAX()`

# %% [markdown]
# The `MAX()` function returns the largest value of the selected column.

# %% [markdown]
# **SELECT `MAX(column_name)`
# FROM table_name
# `WHERE` condition;**

# %% [markdown]
# **SELECT `MAX(Price)` `AS` LargestPrice
# FROM Products;**

# %% [markdown]
# ### 28)  `COUNT()`

# %% [markdown]
# The `COUNT()` function returns the number of rows that matches a specified criterion.

# %% [markdown]
# **SELECT `COUNT(column_name)`
# FROM table_name
# `WHERE` condition;**

# %% [markdown]
# **SELECT `COUNT(ProductID)`
# FROM Products;**

# %% [markdown]
# ### 29) `AVG()`
#
# The `AVG()` function returns the average value of a numeric column.

# %% [markdown]
# **SELECT `AVG(column_name)`
# FROM table_name
# `WHERE` condition;**

# %% [markdown]
# **SELECT `AVG(Price)`
# FROM Products;**

# %% [markdown]
# ### 30) `SUM() `
#
# The `SUM()` function returns the total sum of a numeric column.

# %% [markdown]
# **SELECT `SUM(column_name)`
# FROM table_name
# `WHERE` condition;**

# %% [markdown]
# **SELECT `SUM(Quantity)`
# FROM OrderDetails;**

# %% [markdown]
# # Types of Joins

# %% [markdown]
# **A `JOIN` clause is used to combine rows from two or more tables, based on a related column between them.**

# %% [markdown]
# |Types of Joins in MySQL|Functioning|
# |-----------------------|--------------|
# |INNER JOIN| Returns records that have matching values in both tables|
# |LEFT JOIN| Returns all records from the left table, and the matched records from the right table|
# |RIGHT JOIN| Returns all records from the right table, and the matched records from the left table|
# |CROSS JOIN| Returns all records from both tables|

# %% [markdown]
# ------

# %% [markdown]
# **In SQL, there are several types of joins that can be used to combine data from two or more tables based on a related column between them. The common types of joins are:**
#
# |Types of Joins|Functioning|
# |------------|----------------|
# |Inner Join|Returns only the matching rows from both tables based on the specified condition.|
# |Left Join (or Left Outer Join)|Returns all rows from the left table and the matching rows from the right table based on the specified condition. If no match is found, NULL values are returned for the columns of the right table.|
# |Right Join (or Right Outer Join)|Returns all rows from the right table and the matching rows from the left table based on the specified condition. If no match is found, NULL values are returned for the columns of the left table.|
# |Full Join (or Full Outer Join)|Returns all rows from both tables, combining the result of the left join and the right join. If no match is found, NULL values are returned for the columns of the respective table.|
# |Cross Join (or Cartesian Join)|Returns the Cartesian product of the rows from both tables, meaning it combines each row from the first table with every row from the second table. This join does not require a join condition.|
# |Self Join|When a table is joined with itself based on a related column, it is called a self join. It is useful when you want to compare rows within the same table.|
#
# **These are the main types of joins in SQL. Each type serves a different purpose and can be used based on the specific requirements of your query.**
#
# -------------------

# %% [markdown]
# ![sql-join-chart-custom-poster-size-sql%20%281%29.png](attachment:sql-join-chart-custom-poster-size-sql%20%281%29.png)

# %% [markdown]
# ### 1) `INNER JOIN`  Keyword
#
# The `INNER JOIN` keyword selects records that have matching values in both tables.
#
# **Note:**
#
# * The `INNER JOIN` keyword selects all rows from both tables as long as there is a match between the columns. If there are records in the "Orders" table that do not have matches in "Customers", these orders will not be shown!
#
#
# * Remember that both column names are same on which you have to join the tables.

# %% [markdown]
# ![img_innerjoin.gif](attachment:img_innerjoin.gif)

# %% [markdown]
# **SELECT column_name(s)**
#
# **FROM table1**
#
# **`INNER JOIN` table2**
#
# **`ON` table1.column_name = table2.column_name;**

# %% [markdown]
# -------------

# %% [markdown]
# **SELECT Orders.OrderID, Customers.CustomerName**
#
# **FROM Orders**
#
# **`INNER JOIN` Customers `ON` Orders.CustomerID = Customers.CustomerID;**

# %% [markdown]
# -----------------------------

# %% [markdown]
# ### `JOIN Three Tables`

# %% [markdown]
# **SELECT Orders.OrderID, Customers.CustomerName, Shippers.ShipperName**
#
# **FROM ((Orders**
#
# **`INNER JOIN` Customers `ON` Orders.CustomerID = Customers.CustomerID)**
#
# **`INNER JOIN` Shippers `ON` Orders.ShipperID = Shippers.ShipperID);**

# %% [markdown]
# ### 2) `LEFT JOIN` / `LEFT OUTER JOIN` Keyword
# The `LEFT JOIN` keyword returns all records from the left table (table1), and the matching records (if any) from the right table (table2).

# %% [markdown]
# ![img_leftjoin.gif](attachment:img_leftjoin.gif)

# %% [markdown]
# **SELECT column_name(s)**
#
# **FROM table1**
#
# **`LEFT JOIN` table2**
#
# **`ON` table1.column_name = table2.column_name;**

# %% [markdown]
# -----------------------------------------------------

# %% [markdown]
# **SELECT Customers.CustomerName, Orders.OrderID**
#
# **FROM Customers**
#
# **`LEFT JOIN` Orders `ON` Customers.CustomerID = Orders.CustomerID**
#
# **`ORDER BY` Customers.CustomerName;**

# %% [markdown]
# **Note:** The `LEFT JOIN` keyword returns all records from the left table (Customers), even if there are no matches in the right table (Orders).

# %% [markdown]
# ### 3)  `RIGHT JOIN` / `RIGHT OUTER JOIN` Keyword
#
# The `RIGHT JOIN` keyword returns all records from the right table (table2), and the matching records (if any) from the left table (table1).

# %% [markdown]
# ![img_rightjoin.gif](attachment:img_rightjoin.gif)

# %% [markdown]
# **SELECT column_name(s)**
#
# **FROM table1**
#
# **`RIGHT JOIN` table2**
#
# **`ON` table1.column_name = table2.column_name;**

# %% [markdown]
# -----------------------

# %% [markdown]
# **SELECT Orders.OrderID, Employees.LastName, Employees.FirstName**
#
# **FROM Orders**
#
# **`RIGHT JOIN` Employees `ON` Orders.EmployeeID = Employees.EmployeeID**
#
# **`ORDER BY` Orders.OrderID;**

# %% [markdown]
# **Note:** The `RIGHT JOIN` keyword returns all records from the right table (Employees), even if there are no matches in the left table (Orders).

# %% [markdown]
# ### 4) `CROSS JOIN` Keyword
#
# The `CROSS JOIN` keyword returns all records from both tables (table1 and table2).

# %% [markdown]
# ![img_crossjoin.png](attachment:img_crossjoin.png)

# %% [markdown]
# **SELECT column_name(s)**
#
# **FROM table1**
#
# **`CROSS JOIN` table2;**

# %% [markdown]
# **Note:** `CROSS JOIN` can potentially return very large result-sets!

# %% [markdown]
# ---------------------

# %% [markdown]
# **SELECT Customers.CustomerName, Orders.OrderID**
#
# **FROM Customers**
#
# **`CROSS JOIN` Orders;**

# %% [markdown]
# **Note:** The `CROSS JOIN` keyword returns all matching records from both tables whether the other table matches or not. So, if there are rows in "Customers" that do not have matches in "Orders", or if there are rows in "Orders" that do not have matches in "Customers", those rows will be listed as well.

# %% [markdown]
# ---------------

# %% [markdown]
# If you add a `WHERE` clause (if table1 and table2 has a relationship), the `CROSS JOIN` will produce the same result as the `INNER JOIN` clause:

# %% [markdown]
# **SELECT Customers.CustomerName, Orders.OrderID**
#
# **FROM Customers**
#
# **`CROSS JOIN` Orders**
#
# **`WHERE` Customers.CustomerID=Orders.CustomerID;**

# %% [markdown]
# ### **`SELF JOIN`**
#
#
# * A self join is a regular join in which a table is joined to itself.
#
#
# * Self Join are powerful for comparing values in a column of rows with the same table.

# %% [markdown]
# **SELECT COLUMN_NAMES(s)**
#
# **FROM TABLE1 AS T1**
#
# **`JOIN` TABLE2 AS T2**
#
# **ON T1.COL_NAME=T2.COL_NAME**

# %% [markdown]
# ### 31) `UNION` Operator
#
# The `UNION` operator is used to combine the result-set of two or more `SELECT` statements.
#
# To use UNION Operatore each SELECT Statement must have:
#
# * Every `SELECT` statement within `UNION` must have the same number of columns
#
#
# * The columns must also have similar data types
#
#
# * The columns in every `SELECT` statement must also be in the same order

# %% [markdown]
# **SELECT column_name(s) FROM table1**
#
# **`UNION`**
#
# **SELECT column_name(s) FROM table2;**

# %% [markdown]
# -----

# %% [markdown]
# The following SQL statement returns the cities (only distinct values) from both the "Customers" and the "Suppliers" table:
#
# **SELECT City FROM Customers**
#
# **`UNION`**
#
# **SELECT City FROM Suppliers**
#
# **`ORDER BY` City;**

# %% [markdown]
# **Note:** If some customers or suppliers have the same city, each city will only be listed once, because `UNION` selects only distinct values. Use `UNION ALL` to also select duplicate values!

# %% [markdown]
# -------

# %% [markdown]
# **SELECT City, Country FROM Customers**
#
# **`WHERE` Country='Germany'**
#
# **`UNION`**
#
# **SELECT City, Country FROM Suppliers**
#
# **`WHERE` Country='Germany'**
#
# **`ORDER BY` City;**

# %% [markdown]
# ----------------

# %% [markdown]
# **SELECT 'Customer' `AS` Type, ContactName, City, Country**
#
# **FROM Customers**
#
# **`UNION`**
#
# **SELECT 'Supplier', ContactName, City, Country**
#
# **FROM Suppliers;**

# %% [markdown]
# ### 32) `UNION ALL` Syntax
# The `UNION` operator selects only distinct values by default. To allow duplicate values, use `UNION ALL`:

# %% [markdown]
# **SELECT column_name(s) FROM table1**
#
# **`UNION ALL`**
#
# **SELECT column_name(s) FROM table2;**

# %% [markdown]
# **Note:** The column names in the result-set are usually equal to the column names in the first SELECT statement.

# %% [markdown]
# --------------

# %% [markdown]
# The following SQL statement returns the cities (duplicate values also) from both the "Customers" and the "Suppliers" table:
#
# **SELECT City FROM Customers**
#
# **`UNION ALL`**
#
# **SELECT City FROM Suppliers**
#
# **`ORDER BY` City;**

# %% [markdown]
# ----------

# %% [markdown]
# The following SQL statement returns the German cities (duplicate values also) from both the "Customers" and the "Suppliers" table:
#
# **SELECT City, Country FROM Customers**
#
# **`WHERE` Country='Germany'**
#
# **`UNION ALL`**
#
# **SELECT City, Country FROM Suppliers**
#
# **`WHERE` Country='Germany'**
#
# **`ORDER BY` City;**

# %% [markdown]
# ### 33) `GROUP BY` Statement
# The `GROUP BY` statement groups rows that have the same values into summary rows, like "find the number of customers in each country".
#
# The `GROUP BY` statement is often used with aggregate functions (COUNT(), MAX(), MIN(), SUM(), AVG()) to group the result-set by one or more columns.
#
# **NOTE:-**
#
# * All (*) is not used with `GROUP BY`.
#
#
# * `GROUP BY` Statement is used with aggregate functions.
#
#
# * `HAVING` Clause is used with `GROUP BY`, if you use `WHERE` Clause with `GROUP BY` it will show error.
#
#
# * The column we use with `select` statement is also comes with `group by`. EG : **Select `Mode`, SUM(Amount) From Payment GROUP BY `Mode`;**

# %% [markdown]
# **SELECT column_name(s)**
#
# **FROM table_name**
#
# **`WHERE` condition**
#
# **`GROUP BY` column_name(s)**
#
# **`ORDER BY` column_name(s);**

# %% [markdown]
# -----------------

# %% [markdown]
# The following SQL statement lists the number of customers in each country:
#
# **SELECT `COUNT(CustomerID)`, Country**
#
# **FROM Customers**
#
# **`GROUP BY` Country;**

# %% [markdown]
# -------------------

# %% [markdown]
# The following SQL statement lists the number of customers in each country, sorted high to low:
#
# **SELECT `COUNT(CustomerID)`, Country**
#
# **FROM Customers**
#
# **`GROUP BY` Country**
#
# **`HAVING` `COUNT(CustomerID)` `>` 5**
#
# **`ORDER BY` `COUNT(CustomerID)` `DESC`;**

# %% [markdown]
# ---------------------

# %% [markdown]
# The following SQL statement lists the number of orders sent by each shipper:
#
# **SELECT Shippers.ShipperName, `COUNT(Orders.OrderID)` `AS` NumberOfOrders FROM Orders**
#
# **`LEFT JOIN` Shippers `ON` Orders.ShipperID = Shippers.ShipperID**
#
# **`GROUP BY` ShipperName;**

# %% [markdown]
# ### 34) HAVING Clause
#
# The `HAVING` clause was added to SQL because the `WHERE` keyword cannot be used with `group by` & aggregate functions.
#
#
# The `HAVING` clause is used to apply a filter on the result of GROUP BY based on the specified condition.
#
#
# The `WHERE` clause places conditions on the selected columns, whereas the `HAVING` clause places conditions on groups created by the `GROUP BY` clause.

# %% [markdown]
# **SELECT column_name(s)**
#
# **FROM table_name**
#
# **`WHERE` condition**
#
# **`GROUP BY` column_name(s)**
#
# **`HAVING` condition**
#
# **`ORDER BY` column_name(s);**

# %% [markdown]
# ---------------

# %% [markdown]
# The following SQL statement lists the number of customers in each country. Only include countries with more than 5 customers:
#
# **SELECT `COUNT(CustomerID)`, Country**
#
# **FROM Customers**
#
# **`GROUP BY` Country**
#
# **`HAVING` `COUNT(CustomerID)` > 5;**

# %% [markdown]
# -------

# %% [markdown]
# The following SQL statement lists the number of customers in each country, sorted high to low (Only include countries with more than 5 customers):
#
# **SELECT COUNT(CustomerID), Country**
#
# **FROM Customers**
#
# **`GROUP BY` Country**
#
# **`HAVING` `COUNT(CustomerID)` > 5**
#
# **`ORDER BY` `COUNT(CustomerID) DESC`;**

# %% [markdown]
# -----------

# %% [markdown]
# The following SQL statement lists the employees that have registered more than 10 orders:
#
# **SELECT Employees.LastName, COUNT(Orders.OrderID) AS**
#
# **FROM (Orders**
#
# **`INNER JOIN` Employees `ON` Orders.EmployeeID = Employees.EmployeeID)**
#
# **`GROUP BY` LastName**
#
# **`HAVING` `COUNT(Orders.OrderID)` > 10;**

# %% [markdown]
# --------------

# %% [markdown]
# The following SQL statement lists if the employees "Davolio" or "Fuller" have registered more than 25 orders:
#
# **SELECT Employees.LastName, COUNT(Orders.OrderID) AS NumberOfOrders**
#
# **FROM Orders**
#
# **`INNER JOIN` Employees `ON` Orders.EmployeeID = Employees.EmployeeID**
#
# **`WHERE` LastName = 'Davolio' `OR` LastName = 'Fuller'**
#
# **`GROUP BY` LastName**
#
# **`HAVING` `COUNT(Orders.OrderID)` > 25;**

# %% [markdown]
# ### 35) `EXISTS` Operator
# The `EXISTS` operator is used to test for the existence of any record in a subquery.
#
# The `EXISTS` operator returns TRUE if the subquery returns one or more records.

# %% [markdown]
# **SELECT column_name(s)**
#
# **FROM table_name**
#
# **`WHERE` `EXISTS`**
#
# **(SELECT column_name FROM table_name `WHERE` condition);**

# %% [markdown]
# ---------------

# %% [markdown]
# The following SQL statement returns TRUE and lists the suppliers with a product price less than 20:
#
# **SELECT SupplierName**
#
# **FROM Suppliers**
#
# **`WHERE` `EXISTS` (SELECT ProductName FROM Products `WHERE` Products.SupplierID = Suppliers.supplierID `AND` Price < 20);**

# %% [markdown]
# ------------------

# %% [markdown]
# The following SQL statement returns TRUE and lists the suppliers with a product price equal to 22:
#
# **SELECT SupplierName**
#
# **FROM Suppliers**
#
# **`WHERE` `EXISTS` (SELECT ProductName FROM Products WHERE Products.SupplierID = Suppliers.supplierID AND Price = 22);**
#
# ----------------
#
# **SELECT first_name, last_name From Customers AS C**
#
# **WHERE `EXISTS`(SELECT customer_id, amount FROM Payment AS P WHERE P.customer_id = C.customer_id AND amount > 100)**

# %% [markdown]
# ### 36) `ANY` and `ALL` Operators
# The `ANY` and `ALL` operators allow you to perform a comparison between a single column value and a range of other values.
#
# The `ANY` operator:
#
# returns a boolean value as a result
#
# returns TRUE if ANY of the subquery values meet the condition
#
# `ANY` means that the condition will be true if the operation is true for any of the values in the range.

# %% [markdown]
# **SELECT column_name(s)**
#
# **FROM table_name**
#
# **`WHERE` column_name operator `ANY` (SELECT column_name FROM table_name `WHERE` condition);**
#
# **`Note`: The operator must be a standard comparison operator (=, <>, !=, >, >=, <, or <=).**

# %% [markdown]
# ---------

# %% [markdown]
# The following SQL statement lists the ProductName if it finds ANY records in the OrderDetails table has Quantity equal to 10 (this will return TRUE because the Quantity column has some values of 10):
#
#
# **SELECT ProductName**
#
# **FROM Products**
#
# **`WHERE` ProductID = `ANY` (SELECT ProductID FROM OrderDetails `WHERE` Quantity = 10);**

# %% [markdown]
# ------------

# %% [markdown]
# The following SQL statement lists the ProductName if it finds ANY records in the OrderDetails table has Quantity larger than 99 (this will return TRUE because the Quantity column has some values larger than 99):
#
# **SELECT ProductName**
#
# **FROM Products**
#
# **`WHERE` ProductID = ANY (SELECT ProductID FROM OrderDetails `WHERE`  Quantity > 99);**

# %% [markdown]
# -----------

# %% [markdown]
# The following SQL statement lists the ProductName if it finds ANY records in the OrderDetails table has Quantity larger than 1000 (this will return FALSE because the Quantity column has no values larger than 1000):
#
# **SELECT ProductName**
#
# **FROM Products**
#
# **`WHERE` ProductID = `ANY` (SELECT ProductID FROM OrderDetails `WHERE` Quantity > 1000);**

# %% [markdown]
# ### 37) The `ALL` operator:
#
# returns a boolean value as a result
#
# returns TRUE if `ALL` of the subquery values meet the condition
#
# is used with `SELECT`, `WHERE` and `HAVING` statements
#
# `ALL` means that the condition will be true only if the operation is true for all values in the range.

# %% [markdown]
# **SELECT `ALL` column_name(s)**
#
# **FROM table_name**
#
# **`WHERE` condition;**

# %% [markdown]
# -----

# %% [markdown]
# **SELECT `ALL` ProductName**
#
# **FROM Products**
#
# **`WHERE TRUE`;**

# %% [markdown]
# -------------

# %% [markdown]
# **SELECT column_name(s)**
#
# **FROM table_name**
#
# **`WHERE` column_name operator `ALL`**
#
# **(SELECT column_name FROM table_name `WHERE` condition);**
#
#   **Note: The operator must be a standard comparison operator (=, <>, !=, >, >=, <, or <=).**

# %% [markdown]
# ------------

# %% [markdown]
# The following SQL statement lists the ProductName if ALL the records in the OrderDetails table has Quantity equal to 10. This will of course return FALSE because the Quantity column has many different values (not only the value of 10):
#
# **SELECT ProductName**
#
# **FROM Products**
#
# **`WHERE` ProductID = `ALL` (SELECT ProductID FROM OrderDetails `WHERE` Quantity = 10);**

# %% [markdown]
# ### 38) `INSERT INTO SELECT` Statement
# The `INSERT INTO SELECT` statement copies data from one table and inserts it into another table.
#
# The `INSERT INTO SELECT` statement requires that the data types in source and target tables matches.
#
# **`Note`: The existing records in the target table are unaffected.**

# %% [markdown]
# Copy all columns from one table to another table:
#
# **`INSERT INTO` table2**
#
# ***`SELECT` * FROM table1**
#
# **`WHERE` condition;**

# %% [markdown]
# ----------

# %% [markdown]
# Copy only some columns from one table into another table:
#
# **`INSERT INTO` table2 (column1, column2, column3, ...)**
#
# **`SELECT` column1, column2, column3, ...**
#
# **FROM table1**
#
# **`WHERE` condition;**

# %% [markdown]
# ------------------

# %% [markdown]
# The following SQL statement copies "Suppliers" into "Customers" (the columns that are not filled with data, will contain NULL):
#
# **`INSERT INTO` Customers (CustomerName, City, Country)**
#
# **`SELECT` SupplierName, City, Country FROM Suppliers;**

# %% [markdown]
# --------------

# %% [markdown]
# The following SQL statement copies "Suppliers" into "Customers" (fill all columns):
#
# **`INSERT INTO` Customers (CustomerName, ContactName, Address, City, PostalCode, Country)**
#
# **`SELECT` SupplierName, ContactName, Address, City, PostalCode, Country FROM Suppliers;**

# %% [markdown]
# ------------

# %% [markdown]
# The following SQL statement copies only the German suppliers into "Customers":
#
# **`INSERT INTO` Customers (CustomerName, City, Country)**
#
# **`SELECT` SupplierName, City, Country FROM Suppliers**
#
# **`WHERE` Country='Germany';**

# %% [markdown]
# ### 39.1) Searched  `CASE` Statement
# The `CASE` statement goes through conditions and returns a value when the first condition is met (like an if-then-else statement). So, once a condition is true, it will stop reading and return the result. If no conditions are true, it returns the value in the ELSE clause.
#
# If there is no `ELSE` part and no conditions are true, it returns NULL.
#
# **`CASE`**
#
#    **`WHEN` condition1 `THEN` result1**
#
#    **`WHEN` condition2 `THEN` result2**
#
#    **`WHEN` conditionN `THEN` resultN**
#
#    **`ELSE` result**
#
# **`END`;**

# %% [markdown]
# -----------

# %% [markdown]
# The following SQL goes through conditions and returns a value when the first condition is met:
#
# **SELECT OrderID, Quantity,**
#
# **`CASE`**
#
#    **`WHEN` Quantity > 30 `THEN` 'The quantity is greater than 30'**
#
#    **`WHEN` Quantity = 30 `THEN` 'The quantity is 30'**
#
#    **`ELSE` 'The quantity is under 30'**
#
# **`END` `AS` QuantityText**
#
# **FROM OrderDetails;**

# %% [markdown]
# -------------

# %% [markdown]
# The following SQL will order the customers by City. However, if City is NULL, then order by Country:
#
# **SELECT CustomerName, City, Country**
#
# **FROM Customers**
#
# **`ORDER BY`**
#
# **(CASE**
#
#    **`WHEN` City `IS NULL` `THEN` Country**
#
#    **`ELSE` City**
#
# **`END`);**

# %% [markdown]
# -----------------------

# %% [markdown]
# ### 39.2) Simple `CASE` EXPRESSION
#
# The simple CASE expression compares a single expression to a set of possible values and returns a result based on the first matching condition.
#
# **CASE expression**
#
# **WHEN value1 THEN result1**
#
# **WHEN value2 THEN result2**
#
# **...**
#
# **ELSE default_result**
#
# **END**
#
# --------------
# **SELECT customer_id**
#
# **CASE `amount`**
#
# **WHEN `500` THEN `'Prime Customer'`**
#
# **WHEN `100` THEN `'Plus Customer'`**
#
# **ELSE `'Regular Customer'`**
#
# **END AS `Customer Status`**
#
# **FROM `Payment`**

# %% [markdown]
# ### 40) Operators

# %% [markdown]
# ### `Arithmetic Operators`

# %% [markdown]
# |Operator|	Description|
# |-----------|-----------|
# |+	|Add|
# |-|	Subtract|
# |*	|Multiply|
# |/	|Divide|
# |%	|Modulo|

# %% [markdown]
# ### `Bitwise Operators`
#
# |Operator|	Description|
# |----------|--------------|
# |&	|Bitwise AND|
# | |	Bitwise OR|
# |^|	Bitwise exclusive OR|

# %% [markdown]
# ### `Comparison Operators`
# |Operator	|Description	|
# |--------|------------|
# |=|	Equal to|
# |>|	Greater than|
# |<|	Less than	|
# |>=|	Greater than or equal to|
# |<=|	Less than or equal to|
# |<>|	Not equal to|

# %% [markdown]
# ### `Compound Operators`
#
# |Operator|	Description|
# |-----------|-----------|
# |+=|	Add equals|
# |-=|	Subtract equals|
# |*=|Multiply equals|
# |/=|	Divide equals|
# |%=|	Modulo equals|
# |&=|	Bitwise AND equals|
# |^-=|	Bitwise exclusive equals|
# ||*=|	Bitwise OR equals|

# %% [markdown]
# ### `Logical Operators`
# |Operator|	Description|
# |--------|---------------|
# |ALL	|TRUE if all of the subquery values meet the condition|
# |AND	|TRUE if all the conditions separated by AND is TRUE|
# |ANY	|TRUE if any of the subquery values meet the condition|
# |BETWEEN|	TRUE if the operand is within the range of comparisons|
# |EXISTS|	TRUE if the subquery returns one or more records|
# |IN	|TRUE if the operand is equal to one of a list of expressions|
# |LIKE|	TRUE if the operand matches a pattern	|
# |NOT|	Displays a record if the condition(s) is NOT TRUE|
# |OR	|TRUE if any of the conditions separated by OR is TRUE	|
# |SOME|	TRUE if any of the subquery values meet the condition|

# %% [markdown]
# ### 41) MySQL `CREATE DATABASE` Statement
#
# The `CREATE DATABASE` statement is used to create a new SQL database.

# %% [markdown]
# **`CREATE DATABASE` databasename;**

# %% [markdown]
# ### 42) MySQL `DROP DATABASE` Statement
# The `DROP DATABASE` statement is used to drop an existing SQL database.
#
# **`DROP DATABASE` databasename;**

# %% [markdown]
# ### 43) MySQL `CREATE TABLE` Statement
# The `CREATE TABLE` statement is used to create a new table in a database.
#
# **`CREATE TABLE` table_name (**
#
#    **column1 datatype,**
#
#    **column2 datatype,**
#
#    **column3 datatype,**
#
#    **....**
#
# **);**

# %% [markdown]
# -----

# %% [markdown]
# **`CREATE TABLE` Persons (**
#
#    **PersonID int,**
#
#    **LastName varchar(255),**
#
#    **FirstName varchar(255),**
#
#    **Address varchar(255),**
#
#    **City varchar(255)**
#
# **);**

# %% [markdown]
# The PersonID column is of type int and will hold an integer.
#
# The LastName, FirstName, Address, and City columns are of type varchar and will hold characters, and the maximum length for these fields is 255 characters.

# %% [markdown]
# ------------

# %% [markdown]
# Create Table Using Another Table
#
# A copy of an existing table can also be created using `CREATE TABLE.`
#
# The new table gets the same column definitions. All columns or specific columns can be selected.
#
# If you create a new table using an existing table, the new table will be filled with the existing values from the old table.

# %% [markdown]
# **`CREATE TABLE` new_table_name `AS`**
#
#    **SELECT column1, column2,...**
#
#    **FROM existing_table_name**
#
#    **`WHERE` ....;**
#
#    -----------
#
#    The following SQL creates a new table called "TestTables" (which is a copy of the "Customers" table):
#
# **`CREATE TABLE` TestTable `AS`**
#
# **SELECT customername, contactname**
#
# **FROM customers;**

# %% [markdown]
# ### 44) MySQL `DROP TABLE` Statement
# The `DROP TABLE` statement is used to drop an existing table in a database.
#
# **`DROP TABLE` table_name;**

# %% [markdown]
# ### 45) MySQL `TRUNCATE TABLE`
# The `TRUNCATE TABLE` statement is used to delete the data inside a table, but not the table itself.
#
# **`TRUNCATE TABLE` table_name;**

# %% [markdown]
# ### 46) MySQL `ALTER TABLE` Statement
# The `ALTER TABLE` statement is used to add, delete, or modify columns in an existing table.
#
# The `ALTER TABLE` statement is also used to add and drop various constraints on an existing table.

# %% [markdown]
# ### `ALTER TABLE` - `ADD Column`
#
# To add a column in a table, use the following syntax:
#
# **`ALTER TABLE` table_name**
#
# **`ADD` column_name datatype;**
#
# --------------------------
#
# **`ALTER TABLE` Customers**
#
# **`ADD` Email varchar(255);**

# %% [markdown]
# ------

# %% [markdown]
# ### `ALTER TABLE`  - `DROP COLUMN`
#
# To delete a column in a table, use the following syntax (notice that some database systems don't allow deleting a column):
#
# **`ALTER TABLE` table_name**
#
# **`DROP COLUMN` column_name;**
#
#   -------------
#
# The following SQL deletes the "Email" column from the "Customers" table:
#
#
# **`ALTER TABLE` Customers**
#
# **`DROP COLUMN` Email;**

# %% [markdown]
# --------

# %% [markdown]
# ### `ALTER TABLE` - `MODIFY COLUMN`
# To change the data type of a column in a table, use the following syntax:
#
# **`ALTER TABLE` table_name**
#
# **`MODIFY COLUMN` column_name datatype;**
#
# --------------------
#
# **`ALTER TABLE` Persons**
#
# **`MODIFY COLUMN` DateOfBirth date;**
#
# Notice that the new column, "DateOfBirth", is of type date and is going to hold a date. The data type specifies what type of data the column can hold.

# %% [markdown]
# ### Constraints
#
# • Constraints are used to specify rules for data in a table
#
#
# • This ensures the accuracy and reliability of the data in the table
#
#
# • Constraints can be specified when the table is created with the CREATE TABLE statement, or after the table is created with the ALTER TABLE statement
#
# • **`Syntax`**
#
# CREATE TABLE table_name(
#
# column1 datatype **`constraint`**,
#
# column2 datatype **`constraint`**,
#
# column3 datatype **`constraint`**,);
#
# **`Constraints`**
#
# Commonly used constraints in SQL:
#
# * `NOT NULL` - Ensures that a column cannot have a NULL value
#
#
# * `NIQUE` - Ensures that all values in a column are different
#
#
# * `PRIMARY KEY` - A combination of a NOT NULL and UNIQUE
#
#
# * `FOREIGN KEY` - Prevents actions that would destroy links between tables (used to link multiple tables together)
#
#
# * `CHECK` -Ensures that the values in a column satisfies a specific condition
#
#
# * `DEFAULT` - Sets a default value for a column if no value is specified
#
#
# * `CREATE INDEX` - Used to create and retrieve data from the da very quickly

# %% [markdown]
# ### 47) WINDOW FUNCTIONS
#
# * Windows Functions applies aggregate, ranking and analytic functions over a particular window (set of rows).
#
#
# * And `OVER` Clause is used with window functions to define the window.

# %% [markdown]
# ![1_bWw3tHCsXRHyOKOkm81eUg.png](attachment:1_bWw3tHCsXRHyOKOkm81eUg.png)

# %% [raw]
# SYNTAX
#
# SELECT COLUMN_NAME(S),
#
# fun() OVER([<PARTITION BY Clasue>]
#
#            [<ORDER BY Clause>]
#
#            [<ROW or RANGE Clause])
#
# FROM TABLE_NAME;

# %% [markdown]
# **`FUNCTIONS`**:-
#
# 1) Aggregate Functions
#
#
# 2) Ranking Functions
#
#
# 3) Analytic Functions

# %% [markdown]
# **`DEFINE A WINDOW`**
#
# 1) PARTITION BY
#
#
# 2) ORDER BY
#
#
# 3) ROW or RANGE

# %% [markdown]
# **`WINDOW FUNCTIONS TERM`**
#
#
# • **`Window function`** applies aggregate, ranking and analytic functions over a particular window; for example, sum, avg, or row_number
#
#
# • **`Expression`** is the name of the column that we want the window function operated on. This may not be necessary depending on what window function is used
#
#
# • **`OVER`** is just to signify that this is a window function
#
#
# • **`PARTITION BY`** divides the rows into partitions so we can specify which rows to use to compute the window function
#
#
# • **`ORDER BY`** is used so that we can order the rows within each partition.. This is optional and does not have to be specified
#
#
# • **`ROWS`** can be used if we want to further limit the rows within our partition. This is optional and usually not used

# %% [markdown]
# **`WINDOW FUNCTIONS TYPE`**
#
# Their is no official division of the SQL Window Functions into categories but high level we can divide into three types.

# %% [markdown]
# ![1u8SPxze2b1OdCdPo1maVGw.png](attachment:1u8SPxze2b1OdCdPo1maVGw.png)

# %% [markdown]
# ### `EXAMPLE OF AGGREGATE FUNCTIONS`
#
# **`Note`**: `PARTITION BY` means category wise.
#
# **SELECT new_id, new_cat,**
#
# **SUM(new_id) OVER(PARTITION BY new cat ORDER BY new_id) AS "Total",**
#
# **FROM test_data**
#
# -------------
#
# **SELECT new_id, new_cat,**
#
# **AVG(new_id) OVER(PARTITION BY new_cat ORDER BY new_id) AS "Average",**
#
# **FROM test_data**
#
# --------------------
#
# **SELECT new_id, new_cat,**
#
# **COUNT(new_id) OVER PARTITION BY new cat ORDER BY new_id) AS "Count",**
#
# **FROM test_data**
#
# -------------------
#
# **SELECT new_id, new_cat,**
#
# **MIN(new_id) OVER( PARTITION BY new cat ORDER BY new_id) AS "Min",**
#
# **FROM test_data**
#
# --------------------
#
# **SELECT new_id, new_cat,**
#
# **MAX(new_id) OVER( PARTITION BY new cat ORDER BY new_id) AS "Max"**
#
# **FROM test_data**

# %% [markdown]
# ![WhatsApp%20Image%202023-07-14%20at%2015.51.46.jpg](attachment:WhatsApp%20Image%202023-07-14%20at%2015.51.46.jpg)

# %% [markdown]
# **SELECT new_id, new_cat,**
#
# **SUM(new id) OVER ORDER BY new_id ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS "Total"**
#
# **FROM test data**
#
# ------------------
#
# **SELECT new_id, new_cat,**
#
# **COUNT(new_id) OVER ORDER BY new_id ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS "Count"**
#
# **FROM test data**
#
# --------------------
#
# **SELECT new_id, new_cat,**
#
# **MIN(new_id) OVER( ORDER BY new_id ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS "Min"**
#
# **FROM test data**
#
# --------------------
#
# **SELECT new_id, new_cat,**
#
# **MAX(new_id) OVER ORDER BY new_id ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS "Max"**
#
# **FROM test data**
#
# ------------------------
#
# **SELECT new_id, new_cat,**
#
# **AVG(new_id) OVER ORDER BY new_id ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS "Average"**
#
# **FROM test data**

# %% [markdown]
# ![WhatsApp%20Image%202023-07-14%20at%2015.51.45.jpg](attachment:WhatsApp%20Image%202023-07-14%20at%2015.51.45.jpg)

# %% [markdown]
# ### `EXAMPLE OF RANKING FUNCTIONS`
#
# **SELECT new_id,**
#
# **ROW_NUMBER() OVER( ORDER BY new_id) AS "ROW_NUMBER"**
#
# **FROM test_data**
#
# --------------
#
# **SELECT new_id,**
#
# **RANK() OVER( ORDER BY new_id) AS "RANK"**
#
# **FROM test_data**
#
# --------------------
#
# **SELECT new_id,**
#
# **DENSE_RANK() OVER( ORDER BY new_id) AS "DENSE_RANK"**
#
# **FROM test_data**
#
# --------------------
#
# **SELECT new_id,**
#
# **PERCENT_RANK() OVER( ORDER BY new_id) AS "PERCENT_RANK"**
#
# **FROM test_data**

# %% [markdown]
# ![WhatsApp%20Image%202023-07-14%20at%2016.00.01.jpg](attachment:WhatsApp%20Image%202023-07-14%20at%2016.00.01.jpg)

# %% [markdown]
# ### `EXAMPLE OF VALUE FUNCTIONS`
#
# **SELECT new_id,**
#
# **FIRST VALUE(new_id) OVER( ORDER BY new_id) AS "FIRST_VALUE"**
#
# **FROM test_data**
#
# -------------
#
# **SELECT new_id,**
#
# **LAST_VALUE(new_id) OVER( ORDER BY new_id) AS "LAST_VALUE"**
#
# **FROM test_data**
#
# -----------------
#
# **SELECT new_id,**
#
# **LEAD(new_id) OVER( ORDER BY new_id) AS "LEAD"**
#
# **FROM test_data**
#
# ---------------
#
# **SELECT new_id,**
#
# **FLAG(new_id) OVER( ORDER BY new_id) AS "LAG"**
#
# **FROM test_data**

# %% [markdown]
# ![WhatsApp%20Image%202023-07-14%20at%2016.08.22.jpg](attachment:WhatsApp%20Image%202023-07-14%20at%2016.08.22.jpg)

# %% [markdown]
# **`NOTE`** : If you want the single value from whole column, use :"ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING"

# %% [markdown]
# ![WhatsApp%20Image%202023-07-14%20at%2016.18.50.jpg](attachment:WhatsApp%20Image%202023-07-14%20at%2016.18.50.jpg)

# %% [markdown]
# ![WhatsApp%20Image%202023-07-14%20at%2016.18.50s.jpg](attachment:WhatsApp%20Image%202023-07-14%20at%2016.18.50s.jpg)

# %% [markdown]
# ### `Common Table Expression (CTE)`
#
# * A common table expression, or CTE, is a temporary named result set created from a simple SELECT statement that can be used in a subsequent SELECT statement.
#
#
# * We can define CTES by adding a `WITH` clause directly before SELECT, INSERT, UPDATE, DELETE, or MERGE statement.
#
#
# * The WITH clause can include one or more CTES seprated by commas.

# %% [markdown]
# ![WhatsApp%20Image%202023-07-14%20at%2016.33.52.jpg](attachment:WhatsApp%20Image%202023-07-14%20at%2016.33.52.jpg)

# %% [markdown]
# ### `HOW TO MAKE A SINGLE CTE ?`
#
# ![WhatsApp%20Image%202023-07-14%20at%2016.31.31.jpg](attachment:WhatsApp%20Image%202023-07-14%20at%2016.31.31.jpg)

# %% [markdown]
# ### `How to make 2 CTE?`**
#
# **WITH my cp AS (**
#
# **SELECT AVG(amount) OVER (ORDER BY p.customer_id) AS "Average Price",**
#
# **COUNT(address_id) OVER ORDER BY c.customer_id) AS "Count"**
#
# **FROM payment as p**
#
# **INNER JOIN customer AS C**
#
# **ON p.customer_id = c.customer_id**
#
# **),**
#
# **my_ca AS (**
#
# ***SELECT * FROM customer as c**
#
# **INNER JOIN address AS a**
#
# **ON a.address id =  c.address id**
#
# **INNER JOIN country as cc**
#
# **ON cc.city id = a.city id**
#
# **)**
#
# --------------
#
# ### `QUERY`
#
# **SELECT cp.first name, cp.last name, ca.city, ca.country, cp.amount**
#
# **FROM my_ca as ca, my_cp as cp**
#
# ------------

# %% [markdown]
# ### `OUTPUT`
#
# ![WhatsApp%20Image%202023-07-14%20at%2016.44.44.jpg](attachment:WhatsApp%20Image%202023-07-14%20at%2016.44.44.jpg)

# %% [markdown]
# ### `ADVANCE CTE EXAMPLE`
#
# **WITH my_cte AS (**
#
# **SELECT mode, MAX(amount) AS highest price, SUN (amount) AS total price**
#
# **FROM payment**
#
# **GROUP BY mode**
#
# **)**
#
# -----------
#
# ### `QUERY`
#
# **SELECT payment., my.highest price, my.total price**
#
# **FROM payment**
#
# **JOIN my_cte**
#
# **ON payment.mode = my.mode 9**
#
# **ORDER BY payment.mode**
#
# ----------------
#
# ### `OUTPUT`
#
# ![WhatsApp%20Image%202023-07-14%20at%2016.49.28.jpg](attachment:WhatsApp%20Image%202023-07-14%20at%2016.49.28.jpg)

# %% [markdown]
# # Data Types
#
# ### `String Data Types`

# %% [markdown]
# |Data type|	Description|
# |----------|------------|
# |CHAR(size)|	A FIXED length string (can contain letters, numbers, and special characters). The size parameter specifies the column length in characters - can be from 0 to 255. Default is 1|
# |VARCHAR(size)|	A VARIABLE length string (can contain letters, numbers, and special characters). The size parameter specifies the maximum column length in characters - can be from 0 to 65535|
# |BINARY(size)|	Equal to CHAR(), but stores binary byte strings. The size parameter specifies the column length in bytes. Default is 1|
# |VARBINARY(size)|	Equal to VARCHAR(), but stores binary byte strings. The size parameter specifies the maximum column length in bytes.|
# |TINYBLOB|	For BLOBs (Binary Large OBjects). Max length: 255 bytes|
# |TINYTEXT|	Holds a string with a maximum length of 255 characters|
# |TEXT(size)|	Holds a string with a maximum length of 65,535 bytes|
# |BLOB(size)|	For BLOBs (Binary Large OBjects). Holds up to 65,535 bytes of data|
# |MEDIUMTEXT|	Holds a string with a maximum length of 16,777,215 characters|
# |MEDIUMBLOB|	For BLOBs (Binary Large OBjects). Holds up to 16,777,215 bytes of data|
# |LONGTEXT|	Holds a string with a maximum length of 4,294,967,295 characters|
# |LONGBLOB|	For BLOBs (Binary Large OBjects). Holds up to 4,294,967,295 bytes of data|
# |ENUM(val1, val2, val3, ...)|	A string object that can have only one value, chosen from a list of possible values. You can list up to 65535 values in an ENUM list. If a value is inserted that is not in the list, a blank value will be inserted. The values are sorted in the order you enter them|
# |SET(val1, val2, val3, ...)|	A string object that can have 0 or more values, chosen from a list of possible values. You can list up to 64 values in a SET list|

# %% [markdown]
# ------------

# %% [markdown]
# ### `Numeric Data Types`
#
# |Data type|	Description|
# |-------------|-----------|
# |BIT(size)|	A bit-value type. The number of bits per value is specified in size. The size parameter can hold a value from 1 to 64. The default value for size is 1.|
# |TINYINT(size)|	A very small integer. Signed range is from -128 to 127. Unsigned range is from 0 to 255. The size parameter specifies the maximum display width (which is 255)|
# |BOOL|	Zero is considered as false, nonzero values are considered as true.|
# |BOOLEAN	|Equal to BOOL|
# |SMALLINT(size)|	A small integer. Signed range is from -32768 to 32767. Unsigned range is from 0 to 65535. The size parameter specifies the maximum display width (which is 255)|
# |MEDIUMINT(size)|	A medium integer. Signed range is from -8388608 to 8388607. Unsigned range is from 0 to 16777215. The size parameter specifies the maximum display width (which is 255)|
# |INT(size)|	A medium integer. Signed range is from -2147483648 to 2147483647. Unsigned range is from 0 to 4294967295. The size parameter specifies the maximum display width (which is 255)|
# |INTEGER(size)|	Equal to INT(size)|
# |BIGINT(size)|	A large integer. Signed range is from -9223372036854775808 to 9223372036854775807. Unsigned range is from 0 to 18446744073709551615. The size parameter specifies the maximum display width (which is 255)|
# |FLOAT(size, d)|	A floating point number. The total number of digits is specified in size. The number of digits after the decimal point is specified in the d parameter. This syntax is deprecated in MySQL 8.0.17, and it will be removed in future MySQL versions|
# |FLOAT(p)|	A floating point number. MySQL uses the p value to determine whether to use FLOAT or DOUBLE for the resulting data type. If p is from 0 to 24, the data type becomes FLOAT(). If p is from 25 to 53, the data type becomes DOUBLE()|
# |DOUBLE(size, d)|	A normal-size floating point number. The total number of digits is specified in size. The number of digits after the decimal point is specified in the d parameter|
# |DOUBLE PRECISION(size, d)|	 |
# |DECIMAL(size, d)|	An exact fixed-point number. The total number of digits is specified in size. The number of digits after the decimal point is specified in the d parameter. The maximum number for size is 65. The maximum number for d is 30. The default value for size is 10. The default value for d is 0.|
# |DEC(size, d)|	Equal to DECIMAL(size,d)|

# %% [markdown]
# ------------

# %% [markdown]
# ### `Date and Time Data Types`
# |Data type|	Description|
# |----------|-----------|
# |DATE|	A date. Format: YYYY-MM-DD. The supported range is from '1000-01-01' to '9999-12-31'|
# |DATETIME(fsp)|	A date and time combination. Format: YYYY-MM-DD hh:mm:ss. The supported range is from '1000-01-01 00:00:00' to '9999-12-31 23:59:59'. Adding DEFAULT and ON UPDATE in the column definition to get automatic initialization and updating to the current date and time|
# |TIMESTAMP(fsp)	|A timestamp. TIMESTAMP values are stored as the number of seconds since the Unix epoch ('1970-01-01 00:00:00' UTC). Format: YYYY-MM-DD hh:mm:ss. The supported range is from '1970-01-01 00:00:01' UTC to '2038-01-09 03:14:07' UTC. Automatic initialization and updating to the current date and time can be specified using DEFAULT CURRENT_TIMESTAMP and ON UPDATE CURRENT_TIMESTAMP in the column definition|
# |TIME(fsp)|	A time. Format: hh:mm:ss. The supported range is from '-838:59:59' to '838:59:59'|
# |YEAR|	A year in four-digit format. Values allowed in four-digit format: 1901 to 2155, and 0000. MySQL 8.0 does not support year in two-digit format.|

# %% [markdown]
# ### `TIMESTAMP` DATATYPE
#
# The `TIMESTAMP` data type is used for values that contain both date and time parts
#
# * `TIME` contains only time, format HH:MI:SS
#
#
# * `DATE` contains on date, format YYYY-MM-DD
#
#
# * `YEAR` contains on year, format YYYY or YY
#
#
# * `TIMESTAMP` contains date and time, format YYYY-MM HH:MI:SS
#
#
# * `TIMESTAMPTZ` contains date, time and time zone
#
# ----------------------
#
# ### `TIMESTAMP` functions/operators
#
# Below are the TIMESTAMP functions and operators in SQL:
#
# * SHOW `TIMEZONE` : display the current timezone i.e (Kathmandu, ASIA)
#
#
# * SELECT `NOW()` : retrieve the current timestamp, including both the date and time
#
#
# * SELECT `TIMEOFDAY()` : retrieve the current time of day along with weekday(i.e Thursday) and date
#
#
# * SELECT `CURRENT_TIME` : retrieve the current time, without the date
#
#
# * SELECT `CURRENT_DATE` : retrieve the current date
#
#
# **NOTE : This Functions and Operators are used when you have to create new database or table.**
#
# ----------------
#
# ### `EXTRACT` Function
#
# The `EXTRACT()` function extracts a part from a given date value.
#
# Syntax: **SELECT `EXTRACT(MONTH FROM date_field)` FROM Table**
#
# • `YEAR`
#
#
# • `QUARTER`
#
#
# • `MONTH`
#
#
# • `WEEK`
#
#
# • `DAY`
#
#
# • `HOUR`
#
#
# • `MINUTE`
#
#
# • `QUATER`
#
#
# • `DOW - day of week`
#
#
# • `DOY - day of year`
#
#
# **EG : SELECT `EXTRACT(MONTH FROM Payement_Date)` AS Payement_Month FROM Payment;**
#
#
# It will create a new column where it extracts month from existing column which consists date-month-year.
#
#
# **EG : SELECT `EXTRACT(Year FROM Payement_Date)` AS Payement_Year FROM Payment;**
#
#
# It will create a new column where it extracts Year from existing column which consists date-month-year.
